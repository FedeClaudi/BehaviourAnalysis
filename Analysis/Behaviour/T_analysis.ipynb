# %%
import sys
sys.path.append('./')

from Utilities.imports import *
from Analysis.Behaviour.experiments_analyser import ExperimentsAnalyser
from Analysis.Behaviour.torosity import Torosity

from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D
from scipy.signal import find_peaks

import plotly
import plotly.graph_objs as go
import colorlover as cl

# %matplotlib inline

# %%
# Load data
trials = pd.read_pickle("/Users/federicoclaudi/Dropbox (UCL - SWC)/Rotation_vte/analysis_metadata/threatplatform/aligned_T_tracking.pkl")

# %%
trials
# Out:
#      trial_id                                           tracking  \
# 0         697  [[489.24758257508813, 152.53477198385406, 0.68...
# 1         698  [[499.3421692845867, 156.76128701446976, 0.846...
# 2         699  [[486.4389773682187, 193.62896218492835, 1.109...
# 3         700  [[486.50757826715994, 163.58512537528497, 0.46...
# 4         701  [[486.09065352413006, 164.42956352381293, 1.09...
# 5         702  [[485.3599707081919, 205.8611856919813, 0.2327...
# 6         703  [[482.8008185756622, 173.48008946957043, 0.239...
# 7         704  [[484.9818480952838, 174.8471965596624, 0.7783...
# 8         705  [[nan, nan, nan], [nan, nan, nan], [nan, nan, ...
# 9         706  [[480.6489644756655, 134.93773144772717, 0.225...
# 10        707  [[489.99021421367195, 172.6194122171579, 0.582...
# 11        708  [[479.9386119819751, 184.15191400061337, 0.595...
# 12        709  [[501.96779275587687, 171.73628709057516, 0.22...
# ...
